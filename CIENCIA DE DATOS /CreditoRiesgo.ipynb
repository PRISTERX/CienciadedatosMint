# %%
import pandas as pd
import numpy as np

# %%
# Montar Google Drive en Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Riesgos
# Out:
# /content/drive/MyDrive/Riesgos

# %%
ls
# Out:
# riesgo.xlsx

# %%
df = pd.read_excel("riesgo.xlsx")
df
# Out:
#       Customer_ID            Name        Age          SSN     Occupation  \
# 0      CUS_0x1000  Alistair Barrf  17.375000  913-74-1218         Lawyer
# 1      CUS_0x1009          Arunah  25.750000  063-67-6938       Mechanic
# 2      CUS_0x100b        Shirboni  18.500000  238-62-0395  Media_Manager
# 3      CUS_0x1011       Schneyerh  43.875000  793-05-8223         Doctor
# 4      CUS_0x1013        Cameront  43.750000  930-49-9615       Mechanic
# ...           ...             ...        ...          ...            ...
# 12495   CUS_0xff3     Somervilled  55.000000  726-35-5322      Scientist
# 12496   CUS_0xff4       Poornimaf  36.857143  655-05-7666   Entrepreneur
# 12497   CUS_0xff6        Shieldsb  18.625000  541-92-8371         Doctor
# 12498   CUS_0xffc           Brads  17.375000  226-86-7294       Musician
# 12499   CUS_0xffd        Damouniq  29.250000  832-88-8320      Scientist
#
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12500 entries, 0 to 12499
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer_ID               12500 non-null  object
#  1   Name                      12500 non-null  object
#  2   Age                       12500 non-null  float64
#  3   SSN                       12500 non-null  object
#  4   Occupation                12500 non-null  object
#  5   Annual_Income             12500 non-null  float64
#  6   Monthly_Inhand_Salary     12500 non-null  float64
#  7   Num_Bank_Accounts         12500 non-null  float64
#  8   Num_Credit_Card           12500 non-null  float64
#  9   Interest_Rate             12500 non-null  int64
#  10  Num_of_Loan               12500 non-null  int64
#  11  Type_of_Loan              11074 non-null  object
#  12  Delay_from_due_date       12500 non-null  float64
# ...

# %%
print(df.isnull().sum())
# Out:
# Customer_ID                    0
# Name                           0
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary          0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                1426
# Delay_from_due_date            0
# Num_of_Delayed_Payment         0
# Changed_Credit_Limit           0
# Num_Credit_Inquiries           0
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age             0
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly        0
# Payment_Behaviour              0
# Monthly_Balance                0
# Credit_Score                   0
# dtype: int64

# %%
df.describe().T
# Out:
#                             count          mean           std          min  \
# Age                       12500.0     33.311294     10.760177    14.000000
# Annual_Income             12500.0  50505.123449  38300.762656  7005.930000
# Monthly_Inhand_Salary     12500.0   4198.468568   3187.142979   303.645417
# Num_Bank_Accounts         12500.0      5.368828      2.592493     0.000000
# Num_Credit_Card           12500.0      5.533620      2.066040     0.500000
# Interest_Rate             12500.0     14.532080      8.741636     1.000000
# Num_of_Loan               12500.0      3.532880      2.446442     0.000000
# Delay_from_due_date       12500.0     21.068780     14.772965    -2.000000
# Num_of_Delayed_Payment    12500.0     13.338642      6.153148     0.000000
# Changed_Credit_Limit      12500.0     10.465068      6.445141     0.500000
# Num_Credit_Inquiries      12500.0      5.779694      3.707936     0.000000
# ...

# %%
print(df.dtypes)
# Out:
# Customer_ID                  object
# Name                         object
# Age                         float64
# SSN                          object
# Occupation                   object
# Annual_Income               float64
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts           float64
# Num_Credit_Card             float64
# Interest_Rate                 int64
# Num_of_Loan                   int64
# Type_of_Loan                 object
# Delay_from_due_date         float64
# Num_of_Delayed_Payment      float64
# Changed_Credit_Limit        float64
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt            float64
# Credit_Utilization_Ratio    float64
# Credit_History_Age          float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly     float64
# Payment_Behaviour            object
# Monthly_Balance             float64
# Credit_Score                  int64
# ...

# %% [markdown]
# debemos cmabiar u object tenemos que numerilizarlos

# %%
print(df.columns)
# Out:
# Index(['Customer_ID', 'Name', 'Age', 'SSN', 'Occupation', 'Annual_Income',
#        'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %% [markdown]
# para borra las columnas

# %% [markdown]
# vamos a quitar las columnas el Customerid

# %%
columnas_eliminar = ['Customer_ID', 'Name', 'SSN', 'Type_of_Loan']
df.drop(columnas_eliminar, axis=1, inplace=True)

# %%
columnas_objeto = df.select_dtypes(include='object').columns
print(columnas_objeto.tolist())
# Out:
# ['Occupation', 'Credit_Mix', 'Payment_of_Min_Amount', 'Payment_Behaviour']

# %%
# Contar instancias (filas) de cada columna tipo object
for columna in df.select_dtypes(include='object').columns:
    print(f'\n📌 Columna: {columna}')
    print(f'   Total instancias: {df[columna].count()}')
    print(f'   Valores únicos:   {df[columna].nunique()}')
    print(df[columna].value_counts())
    print('-' * 50)
# Out:
# 📌 Columna: Occupation
#    Total instancias: 12500
#    Valores únicos:   15
# Occupation
# Lawyer           887
# Engineer         858
# Architect        853
# Mechanic         847
# Scientist        843
# Accountant       843
# Media_Manager    840
# Developer        840
# Teacher          834
# Entrepreneur     831
# Doctor           821
# Journalist       817
# Manager          804
# Musician         794
# Writer           788
# Name: count, dtype: int64
# --------------------------------------------------
#
# 📌 Columna: Credit_Mix
#    Total instancias: 12500
#    Valores únicos:   3
# Credit_Mix
# Standard    5731
# Good        3798
# Bad         2971
# Name: count, dtype: int64
# --------------------------------------------------
#
# 📌 Columna: Payment_of_Min_Amount
#    Total instancias: 12500
#    Valores únicos:   3
# Payment_of_Min_Amount
# Yes    7360
# No     5031
# NM      109
# Name: count, dtype: int64
# --------------------------------------------------
#
# ...

# %%
# Ver la cardinalidad de Credit_Mix
print('Cardinalidad (# de valores únicos):', df['Credit_Mix'].nunique())
print('\nValores únicos:', df['Credit_Mix'].unique())
# Out:
# Cardinalidad (# de valores únicos): 3
#
# Valores únicos: ['Bad' 'Standard' 'Good']

# %% [markdown]
# Vamos a eliminar la profesion y el comportamiento del pago , tiene un cardinalidad alta pero basicamnete para agilizar el ejercicisio

# %%
df.drop(columns=['Payment_Behavior'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1175/1312823831.py in <cell line: 0>()
# ----> 1 df.drop(columns=['Payment_Behavior'], axis=1, inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
# Mostrar los 10 primeros datos de la columna Credit_Score
df['Credit_Score'].head(10)
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    1
# 5    2
# 6    0
# 7    1
# 8    2
# 9    1
# Name: Credit_Score, dtype: int64

# %%
# Ver los valores únicos de Credit_Score
df['Credit_Score'].unique()
df
# Out:
#              Age     Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0      17.375000         Lawyer      30625.940            2706.161667
# 1      25.750000       Mechanic      52312.680            4250.390000
# 2      18.500000  Media_Manager     113781.390            9549.782500
# 3      43.875000         Doctor      58918.470            5208.872500
# 4      43.750000       Mechanic      98620.980            7962.415000
# ...          ...            ...            ...                    ...
# 12495  55.000000      Scientist      17032.785            1176.398750
# 12496  36.857143   Entrepreneur      25546.260            2415.855000
# 12497  18.625000         Doctor     117639.920            9727.326667
# 12498  17.375000       Musician      60877.170            5218.097500
# 12499  29.250000      Scientist      41398.440            3749.870000
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# ...

# %%
X = df.drop(columns=["Credit_Score"])
Y = to_categorical(df["Credit_Score"],num_classes=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1175/3070684394.py in <cell line: 0>()
#       1 X = df.drop(columns=["Credit_Score"])
# ----> 2 Y = to_categorical(df["Credit_Score"],num_classes=3)
#
# NameError: name 'to_categorical' is not defined
